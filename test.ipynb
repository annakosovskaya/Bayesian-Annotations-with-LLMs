# %%
import argparse
import os
from collections import defaultdict
from pathlib import Path
from typing import Dict, List, Optional, Tuple
import gc

import numpy as np
from sympy.logic.boolalg import Boolean
from tqdm import tqdm

from jax import nn, random, vmap, clear_caches
import jax.numpy as jnp

import numpyro
from numpyro import handlers
import numpyro.distributions as dist
from numpyro.infer import MCMC, NUTS, Predictive
from numpyro.infer.reparam import LocScaleReparam
from numpyro.ops.indexing import Vindex

import json

from sklearn.metrics import log_loss,f1_score
from sklearn.preprocessing import OneHotEncoder

from utils.data_utils import read_jsonl

from scipy.stats import entropy
from scipy.spatial.distance import jensenshannon

# %%
res = read_jsonl("data/ghc_train.jsonl")
annotators = np.array([np.array(it["annotators"]) for it in res if len(it["annotators"]) == 3])
annotations = np.array([np.array(it["labels"]) for it in res if len(it["annotators"]) == 3])
logits = np.load("llm_data/Qwen2.5-32B/train/logits.npy")
logits = np.array([x for i, x in enumerate(logits[:, :2]) if len(res[i]["annotators"]) == 3])

# %%
def item_difficulty(annotations,logits,mask=None):
    """
    This model corresponds to the plate diagram in Figure 5 of reference [1].
    """
    num_classes = int(np.max(annotations)) + 1
    num_items, num_positions = annotations.shape

    with numpyro.plate("class", num_classes):
        eta = numpyro.sample(
            "eta", dist.Normal(0, 1).expand([num_classes - 1]).to_event(1)
        )
        chi = numpyro.sample(
            "Chi", dist.HalfNormal(1).expand([num_classes - 1]).to_event(1)
        )

    with numpyro.plate("item", num_items, dim=-2):
        c = numpyro.sample("c", dist.Categorical(logits = logits[:,np.newaxis,:]), infer={"enumerate": "parallel"})

        with handlers.reparam(config={"theta": LocScaleReparam(0)}):
            theta = numpyro.sample("theta", dist.Normal(eta[c], chi[c]).to_event(1))
            theta = jnp.pad(theta, [(0, 0)] * (jnp.ndim(theta) - 1) + [(0, 1)])

        with numpyro.plate("position", num_positions):
            numpyro.sample("y", dist.Categorical(logits=theta), obs=annotations, obs_mask=mask)

# %%
def multinomial(num_classes, num_items, num_positions, annotations=None,logits=None,mask=None):
    """
    This model corresponds to the plate diagram in Figure 1 of reference [1].
    """
    # num_classes = int(np.max(annotations)) + 1
    # num_items, num_positions = annotations.shape

    with numpyro.plate("class", num_classes):
        zeta = numpyro.sample("zeta", dist.Dirichlet(jnp.ones(num_classes)))

    if logits is None:
        pi = numpyro.sample("pi", dist.Dirichlet(jnp.ones(num_classes)))
    # pi = numpyro.sample("pi", dist.Dirichlet(jnp.ones(num_classes)),obs=nn.softmax(logits).mean(0))
    # pi = nn.softmax(logits).mean(0)
    # c = numpyro.sample("c", dist.Categorical(logits = logits[:,np.newaxis,:]), infer={"enumerate": "parallel"})

    with numpyro.plate("item", num_items, dim=-2):
        if logits is None:
            c = numpyro.sample("c", dist.Categorical(probs=pi), infer={"enumerate": "parallel"})
        else:
            c = numpyro.sample("c", dist.Categorical(logits = logits[:,np.newaxis,:]), infer={"enumerate": "parallel"})

        with numpyro.plate("position", num_positions):
            # if test:
            #     numpyro.sample("y", dist.Categorical(zeta[c]))
            # else:
                numpyro.sample("y", dist.Categorical(zeta[c]), obs=annotations, obs_mask=mask)

# %%
with numpyro.handlers.seed(rng_seed=1):
    trace = numpyro.handlers.trace(multinomial).get_trace(3,annotations.shape[0], 3, annotations, logits, mask)
print(numpyro.util.format_shapes(trace))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 2
#       1 with numpyro.handlers.seed(rng_seed=1):
# ----> 2     trace = numpyro.handlers.trace(multinomial).get_trace(3,annotations.shape[0], 3, annotations, logits, mask)
#       3 print(numpyro.util.format_shapes(trace))
#
# NameError: name 'mask' is not defined

# %%
model = item_difficulty

mcmc = MCMC(
    NUTS(model),
    num_warmup=10,
    num_samples=10,
    num_chains=1,
    progress_bar=False if "NUMPYRO_SPHINXBUILD" in os.environ else True,
)

train_size=round(annotations.shape[0]*0.9)
#
# train_data = (
#     (annotations[:train_size], logits[:train_size])
#     if model in [multinomial, item_difficulty]
#     else (positions_, annotations_[:train_size], masks_[:train_size], global_num_classes, True, logits[:train_size])
#     if model == dawid_skene
#     else (annotators[:train_size], annotations[:train_size], logits[:train_size])
# )
#
# test_data = (
#     (annotations[train_size:], logits[train_size:], [True] * annotations[train_size:].shape[0])
#     if model in [multinomial, item_difficulty]
#     else (positions_, annotations_[train_size:], masks_[train_size:], global_num_classes, True, logits[train_size:], [True] * annotations[train_size:].shape[0])
#     if model == dawid_skene
#     else (annotators[train_size:], annotations[train_size:], logits[train_size:], [True] * annotations[train_size:].shape[0])
# )


mask=jnp.array([True]*train_size + [False]*(annotations.shape[0]-train_size)).reshape(-1,1)
mask=jnp.tile(mask,(1,3))
train_data = (
    (annotations,logits, mask)
    if model in [multinomial, item_difficulty]
    else (positions_, annotations_[:train_size], masks_[:train_size], global_num_classes, True, logits[:train_size])
    if model == dawid_skene
    else (annotators[:train_size], annotations[:train_size], logits[:train_size])
)

mcmc.run(random.PRNGKey(0), *train_data)
mcmc.print_summary()

posterior_samples = mcmc.get_samples()
predictive = Predictive(model, posterior_samples, infer_discrete=True)
# discrete_samples = predictive(random.PRNGKey(1), *test_data)
discrete_samples = predictive(random.PRNGKey(1), *train_data)

annotator_probs = vmap(lambda x: x.mean(0), in_axes=1)(
    discrete_samples["y_unobserved"][:,train_size:],
)

pred_probs = np.vstack((annotator_probs.mean(1),1-annotator_probs.mean(1)))
emp_probs = np.vstack((annotations[train_size:].mean(1),1-annotations[train_size:].mean(1)))

print(f'Average Jensen-Shannon divergence across items= {np.power(jensenshannon(emp_probs,pred_probs),2).mean()}')
print(f'Average KL divergence across items= {entropy(emp_probs,pred_probs).mean()}')
print(f'Binary F1 score with majority vote = {f1_score(np.rint(annotations[train_size:].mean(1)),np.rint(np.rint(annotator_probs).mean(1)),pos_label=1)}')
# Out:
# C:\Users\Benson\AppData\Local\Temp\ipykernel_24416\2319423803.py:40: FutureWarning: Some algorithms will automatically enumerate the discrete latent site y_unobserved of your model. In the future, enumerated sites need to be marked with `infer={'enumerate': 'parallel'}`.
#   mcmc.run(random.PRNGKey(0), *train_data)
# sample: 100%|██████████| 20/20 [02:16<00:00,  6.81s/it, 255 steps of size 1.86e-02. acc. prob=0.91]
# C:\Users\Benson\miniconda3\envs\pyro\lib\site-packages\numpyro\diagnostics.py:202: RuntimeWarning: divide by zero encountered in divide
#   n_eff = np.prod(x.shape[:2]) / tau
#                                  mean       std    median      5.0%     95.0%     n_eff     r_hat
#                    Chi[0,0]      0.13      0.14      0.10      0.00      0.41      2.98      2.75
#                    Chi[1,0]      0.40      0.23      0.53      0.02      0.60      3.21      1.76
#                    eta[0,0]      2.79      0.02      2.79      2.76      2.83      9.42      0.91
#                    eta[1,0]      0.26      0.02      0.25      0.23      0.30      5.09      1.37
#     theta_decentered[0,0,0]      0.18      0.91      0.12     -1.27      1.73     30.91      0.90
#     theta_decentered[1,0,0]     -0.00      1.31      0.11     -1.77      1.64     84.37      0.94
#     theta_decentered[2,0,0]      0.04      1.50      0.10     -2.00      1.83     30.32      0.94
#     theta_decentered[3,0,0]     -0.20      0.45     -0.17     -0.79      0.49     15.54      0.94
#     theta_decentered[4,0,0]      0.07      0.62      0.03     -0.95      0.89     24.28      0.92
#     theta_decentered[5,0,0]     -0.05      0.91     -0.00     -1.85      1.76     22.69      0.90
#     theta_decentered[6,0,0]     -0.02      1.18      0.02     -1.43      1.47     62.91      0.94
#     theta_decentered[7,0,0]     -0.08      0.61     -0.32     -0.79      0.78    -91.19      0.90
#     theta_decentered[8,0,0]     -0.18      0.67     -0.24     -1.39      1.13     45.29      0.90
#     theta_decentered[9,0,0]     -0.54      1.61     -0.36     -2.75      1.89     29.13      0.90
#    theta_decentered[10,0,0]      0.10      1.32      0.07     -1.61      1.91     76.71      0.95
#    theta_decentered[11,0,0]      0.05      0.63      0.02     -0.97      1.21     32.62      0.92
#    theta_decentered[12,0,0]      0.10      0.24      0.08     -0.28      0.49     38.10      0.91
#    theta_decentered[13,0,0]     -0.09      0.89     -0.04     -1.45      1.07    112.94      0.92
#    theta_decentered[14,0,0]     -0.35      0.51     -0.50     -0.97      0.65      9.43      1.08
#    theta_decentered[15,0,0]      0.12      0.74      0.01     -1.05      1.35     82.31      0.95
#    theta_decentered[16,0,0]     -0.30      1.32     -0.14     -2.10      1.48    127.16      0.93
#    theta_decentered[17,0,0]     -0.07      1.27      0.05     -1.95      1.97     56.80      0.92
#    theta_decentered[18,0,0]      0.10      0.61      0.23     -0.86      0.95     23.47      0.89
#    theta_decentered[19,0,0]      0.17      1.15      0.60     -1.40      1.48  -1343.62      0.91
#    theta_decentered[20,0,0]      0.03      0.61      0.02     -0.78      0.94     13.08      0.99
#    theta_decentered[21,0,0]      0.07      0.68      0.08     -1.05      1.06     43.39      0.91
#    theta_decentered[22,0,0]      0.11      1.47      0.31     -1.76      1.73     77.20      0.91
#    theta_decentered[23,0,0]      0.15      2.40     -0.02     -2.77      3.16     35.21      0.95
#    theta_decentered[24,0,0]      0.05      1.18      0.14     -1.60      1.65     57.00      0.91
#    theta_decentered[25,0,0]     -0.24      1.12     -0.20     -2.00      1.91     15.54      0.91
#    theta_decentered[26,0,0]      0.16      0.94     -0.06     -1.36      1.57     50.84      0.97
#    theta_decentered[27,0,0]      0.12      1.55     -0.01     -2.08      2.23     40.12      0.94
#    theta_decentered[28,0,0]      0.07      0.41      0.03     -0.58      0.59   -149.21      0.91
#    theta_decentered[29,0,0]     -0.02      0.78     -0.09     -1.56      1.59    170.33      0.90
#    theta_decentered[30,0,0]     -0.06      0.99     -0.05     -1.24      1.34     34.93      0.92
#    theta_decentered[31,0,0]      0.22      1.27      0.20     -1.70      2.10    -50.64      0.90
#    theta_decentered[32,0,0]     -0.10      0.90     -0.02     -1.61      1.50     24.40      0.91
#    theta_decentered[33,0,0]     -0.23      0.67     -0.27     -1.16      0.99     33.08      1.02
#    theta_decentered[34,0,0]      0.17      1.01      0.43     -1.65      1.66     77.67      0.90
#    theta_decentered[35,0,0]     -0.06      1.07      0.10     -1.77      1.23     28.94      0.89
#    theta_decentered[36,0,0]      0.08      0.86      0.07     -1.21      1.55    218.44      0.95
#    theta_decentered[37,0,0]      0.07      0.51     -0.01     -0.52      1.02     45.52      0.92
#    theta_decentered[38,0,0]     -0.48      1.42     -0.66     -2.34      2.16     18.65      0.96
#    theta_decentered[39,0,0]     -0.13      1.04     -0.17     -1.65      1.04     13.13      1.03
#    theta_decentered[40,0,0]      0.14      0.79      0.04     -0.75      1.24     83.06      0.95
#    theta_decentered[41,0,0]     -0.16      1.11     -0.02     -1.86      1.81     20.35      0.95
#    theta_decentered[42,0,0]      0.03      0.88      0.08     -1.46      1.60    212.75      0.90
#    theta_decentered[43,0,0]      0.13      0.68      0.03     -0.66      1.12     24.78      0.93
#    theta_decentered[44,0,0]     -0.06      1.40     -0.01     -1.68      1.71     38.90      0.93
#    theta_decentered[45,0,0]      0.01      0.55      0.01     -0.76      1.01     60.70      0.91
#    theta_decentered[46,0,0]      0.01      1.18      0.04     -1.60      1.78     30.11      0.92
#    theta_decentered[47,0,0]      0.01      0.92      0.14     -1.76      1.47     54.42      0.89
#    theta_decentered[48,0,0]     -0.08      1.22     -0.58     -1.63      1.81    229.74      0.90
#    theta_decentered[49,0,0]      0.05      0.54      0.10     -0.98      0.97     66.11      0.90
#    theta_decentered[50,0,0]     -0.06      0.42     -0.20     -0.54      0.81     94.97      0.91
#    theta_decentered[51,0,0]      0.17      1.79      0.02     -2.82      3.15     21.67      0.94
#    theta_decentered[52,0,0]     -0.05      1.03      0.02     -1.73      1.76     33.13      0.94
#    theta_decentered[53,0,0]     -0.03      0.29     -0.11     -0.41      0.54     27.86      0.89
#    theta_decentered[54,0,0]     -0.09      0.95     -0.11     -1.57      1.66     37.41      0.90
#    theta_decentered[55,0,0]      0.27      2.10     -0.04     -2.85      2.96     73.69      0.92
#    theta_decentered[56,0,0]     -0.33      0.72     -0.47     -1.15      0.81     70.82      0.90
#    theta_decentered[57,0,0]      0.03      1.20      0.14     -2.48      2.32    165.01      0.90
#    theta_decentered[58,0,0]     -0.18      0.91      0.04     -1.36      1.14     23.81      1.02
#    theta_decentered[59,0,0]     -0.11      1.22      0.02     -2.50      2.39     48.19      0.90
#    theta_decentered[60,0,0]     -0.01      1.24      0.08     -2.02      2.08     52.28      0.92
#    theta_decentered[61,0,0]      0.08      0.90      0.14     -1.61      1.49    515.67      0.90
#    theta_decentered[62,0,0]      0.03      0.87     -0.07     -1.52      1.51     31.57      0.91
#    theta_decentered[63,0,0]      0.35      0.53      0.41     -0.55      1.23     12.27      1.03
#    theta_decentered[64,0,0]      0.01      0.84     -0.02     -1.10      1.48 51777785.42      0.91
#    theta_decentered[65,0,0]     -0.10      1.45     -0.06     -2.42      2.71     28.23      0.90
#    theta_decentered[66,0,0]     -0.11      1.01     -0.11     -1.49      1.54     40.19      0.90
#    theta_decentered[67,0,0]     -0.02      0.86     -0.04     -1.51      1.86     94.75      0.91
#    theta_decentered[68,0,0]      0.05      1.18      0.01     -1.71      1.61   -254.37      0.92
#    theta_decentered[69,0,0]     -0.04      0.60     -0.03     -0.95      0.94     24.09      0.91
#    theta_decentered[70,0,0]     -0.22      1.25      0.00     -2.36      1.85     15.99      0.97
#    theta_decentered[71,0,0]      0.34      1.27      1.07     -1.32      1.52    -29.33      0.90
#    theta_decentered[72,0,0]     -0.04      1.07      0.00     -1.52      1.54     37.28      0.93
#    theta_decentered[73,0,0]      0.13      2.70      0.14     -3.03      3.14     26.36      0.92
#    theta_decentered[74,0,0]     -0.04      1.17     -0.23     -1.88      2.13    104.60      0.90
#    theta_decentered[75,0,0]     -0.06      1.18     -0.09     -1.87      1.80    107.57      0.91
#    theta_decentered[76,0,0]      0.08      1.13      0.03     -1.64      1.81   -381.99      0.90
#    theta_decentered[77,0,0]     -0.11      0.51     -0.05     -0.99      0.67      9.67      0.92
#    theta_decentered[78,0,0]     -0.05      0.75     -0.17     -0.99      1.05     78.76      0.90
#    theta_decentered[79,0,0]      0.03      0.98      0.18     -1.22      1.05   -130.53      0.92
#    theta_decentered[80,0,0]      0.06      0.47      0.00     -0.71      0.74    104.28      0.92
#    theta_decentered[81,0,0]      0.05      1.73     -0.10     -2.39      2.42    361.83      0.93
#    theta_decentered[82,0,0]      0.04      0.96      0.01     -0.95      1.26     35.73      0.94
#    theta_decentered[83,0,0]      0.02      0.88     -0.12     -1.37      1.65    242.62      0.90
#    theta_decentered[84,0,0]      0.26      0.92      0.33     -1.04      1.88     17.53      0.94
#    theta_decentered[85,0,0]      0.13      1.17      0.16     -2.20      2.39     69.27      0.89
#    theta_decentered[86,0,0]     -0.10      0.68     -0.13     -1.06      0.95     46.98      0.97
#    theta_decentered[87,0,0]      0.13      1.77     -0.01     -2.65      2.79     37.74      0.93
#    theta_decentered[88,0,0]      0.04      1.28     -0.07     -2.21      2.21   -437.46      0.90
#    theta_decentered[89,0,0]      0.04      1.50     -0.07     -1.49      1.83     37.21      0.95
#    theta_decentered[90,0,0]     -0.10      0.60     -0.14     -1.08      0.92     10.54      0.92
#    theta_decentered[91,0,0]      0.11      0.68      0.22     -1.02      1.06     16.18      0.90
#    theta_decentered[92,0,0]      0.21      0.53      0.17     -0.73      0.90     23.04      0.90
#    theta_decentered[93,0,0]      0.05      0.70      0.03     -0.90      1.13     36.29      0.92
#    theta_decentered[94,0,0]      0.18      0.78      0.38     -0.78      1.11    -17.52      0.90
#    theta_decentered[95,0,0]      0.02      1.13      0.06     -1.24      1.23     29.51      0.94
#    theta_decentered[96,0,0]     -0.17      0.64     -0.31     -1.01      0.80   -103.79      0.90
#    theta_decentered[97,0,0]     -0.52      1.50     -0.05     -2.28      1.25   1124.23      0.91
#    theta_decentered[98,0,0]     -0.02      0.91      0.00     -1.50      1.25  -1366.02      0.89
#    theta_decentered[99,0,0]      0.07      1.47      0.06     -2.16      1.82    120.76      0.95
#   theta_decentered[100,0,0]     -0.16      0.70     -0.11     -1.20      0.97     25.96      0.96
#   theta_decentered[101,0,0]      0.13      0.39      0.14     -0.41      0.70     66.19      0.90
#   theta_decentered[102,0,0]      0.03      0.28     -0.03     -0.32      0.52     17.91      0.95
#   theta_decentered[103,0,0]      0.02      1.16      0.09     -1.52      1.30     31.45      0.95
#   theta_decentered[104,0,0]      0.02      1.04      0.05     -1.68      1.70     36.03      0.91
#   theta_decentered[105,0,0]     -0.09      0.73     -0.06     -1.40      1.15    -84.15      0.91
#   theta_decentered[106,0,0]     -0.04      0.40     -0.06     -0.71      0.82     54.36      0.89
#   theta_decentered[107,0,0]      0.03      1.02     -0.02     -1.44      1.78  -1411.68      0.96
#   theta_decentered[108,0,0]     -0.05      0.83     -0.28     -1.51      1.46     60.31      0.90
#   theta_decentered[109,0,0]     -0.12      1.93      0.01     -2.44      2.56    222.03      0.94
#   theta_decentered[110,0,0]      0.10      0.72      0.01     -1.20      1.28     26.69      0.92
#   theta_decentered[111,0,0]      0.07      0.98     -0.01     -1.63      1.56     49.85      0.91
#   theta_decentered[112,0,0]      0.10      1.19      0.07     -1.71      1.70    157.53      0.92
#   theta_decentered[113,0,0]     -0.08      0.69     -0.15     -1.27      0.87     36.30      0.91
#   theta_decentered[114,0,0]      0.10      1.23     -0.12     -1.19      2.15   3997.43      0.99
#   theta_decentered[115,0,0]     -0.03      0.61     -0.06     -1.03      1.20    351.25      0.92
#   theta_decentered[116,0,0]      0.01      1.02      0.03     -1.20      1.26     36.85      0.93
#   theta_decentered[117,0,0]      0.15      0.62      0.20     -0.95      0.90     55.27      0.91
#   theta_decentered[118,0,0]      0.14      0.99      0.43     -1.65      1.79     39.92      0.89
#   theta_decentered[119,0,0]     -0.11      1.15      0.03     -1.79      1.39    753.93      0.90
#   theta_decentered[120,0,0]      0.33      0.67      0.48     -0.82      1.39    169.63      1.07
#   theta_decentered[121,0,0]      0.21      1.79      0.07     -1.97      2.28    197.63      0.94
#   theta_decentered[122,0,0]      0.02      0.76      0.18     -1.00      0.92     33.43      1.00
#   theta_decentered[123,0,0]      0.01      0.55     -0.00     -0.86      1.04     68.23      0.92
#   theta_decentered[124,0,0]      0.12      0.78      0.29     -1.05      0.97    -43.64      0.90
#   theta_decentered[125,0,0]      0.05      0.49     -0.00     -1.06      0.92    199.17      0.89
#   theta_decentered[126,0,0]     -0.02      0.29     -0.10     -0.38      0.37     39.71      0.90
#   theta_decentered[127,0,0]     -0.10      1.19     -0.07     -2.08      1.49     53.93      0.94
#   theta_decentered[128,0,0]     -0.09      1.04     -0.07     -1.27      1.40    137.12      0.91
#   theta_decentered[129,0,0]     -0.19      0.90     -0.16     -1.33      1.35     22.25      0.96
#   theta_decentered[130,0,0]     -0.01      0.46     -0.02     -0.52      0.62     23.79      0.93
#   theta_decentered[131,0,0]      0.03      0.35      0.06     -0.56      0.74     38.77      0.90
#   theta_decentered[132,0,0]     -0.12      1.15     -0.03     -1.78      1.72     20.75      0.96
#   theta_decentered[133,0,0]     -0.18      0.26     -0.14     -0.72      0.29     10.50      1.06
#   theta_decentered[134,0,0]     -0.03      0.87     -0.26     -1.28      1.06    130.49      1.01
#   theta_decentered[135,0,0]      0.03      0.51      0.14     -0.63      0.92    166.43      0.92
#   theta_decentered[136,0,0]     -0.01      1.21      0.02     -1.55      1.65    296.10      0.93
#   theta_decentered[137,0,0]      0.04      0.61      0.05     -0.96      0.84     29.74      0.90
#   theta_decentered[138,0,0]     -0.15      0.37     -0.20     -0.63      0.36     11.59      1.27
#   theta_decentered[139,0,0]     -0.02      0.53      0.02     -0.80      0.67     22.29      0.93
#   theta_decentered[140,0,0]      0.46      1.22      0.15     -1.67      2.07     34.99      1.02
#   theta_decentered[141,0,0]      0.36      0.90      0.42     -1.21      1.45     19.21      0.95
#   theta_decentered[142,0,0]     -0.00      0.73     -0.13     -0.95      1.03     22.55      0.90
#   theta_decentered[143,0,0]      0.31      0.58      0.30     -0.65      1.16     36.87      0.90
#   theta_decentered[144,0,0]      0.17      0.61     -0.01     -0.60      1.16     16.54      0.93
#   theta_decentered[145,0,0]     -0.10      0.54     -0.09     -0.96      0.93     49.13      0.90
#   theta_decentered[146,0,0]      0.43      1.02      0.09     -0.76      1.78     35.17      0.89
#   theta_decentered[147,0,0]     -0.18      0.93     -0.17     -1.52      1.52   -227.18      0.91
#   theta_decentered[148,0,0]     -0.25      0.99     -0.67     -1.47      1.34   -256.22      0.89
#   theta_decentered[149,0,0]      0.08      0.44      0.02     -0.54      1.04     18.30      1.02
#   theta_decentered[150,0,0]     -0.59      0.34     -0.63     -1.01      0.02      4.24      1.77
#   theta_decentered[151,0,0]     -0.04      0.61     -0.24     -0.87      0.80     33.92      0.90
#   theta_decentered[152,0,0]     -0.02      2.05     -0.00     -2.47      2.75     41.13      0.92
#   theta_decentered[153,0,0]      0.04      0.21     -0.00     -0.25      0.36     27.27      0.91
#   theta_decentered[154,0,0]      0.09      1.49      0.04     -1.72      1.96     28.39      0.93
#   theta_decentered[155,0,0]      0.07      0.88      0.11     -1.52      1.57    -48.75      0.90
#   theta_decentered[156,0,0]      0.01      1.21     -0.01     -1.98      1.86    143.13      0.92
#   theta_decentered[157,0,0]      0.01      0.63      0.00     -0.78      1.02     32.41      0.95
#   theta_decentered[158,0,0]     -0.06      2.01     -0.03     -2.55      2.78     74.82      0.94
#   theta_decentered[159,0,0]     -0.21      0.51     -0.19     -1.07      0.60     10.15      1.08
#   theta_decentered[160,0,0]     -0.03      1.03     -0.04     -1.61      1.62    109.78      0.91
#   theta_decentered[161,0,0]     -0.04      1.39      0.05     -1.67      1.71     26.18      0.94
#   theta_decentered[162,0,0]      0.05      1.78      0.02     -1.98      2.24     41.97      0.96
#   theta_decentered[163,0,0]      0.01      0.77      0.02     -1.13      1.46     42.60      0.90
#   theta_decentered[164,0,0]      0.05      1.52     -0.02     -1.55      1.82     69.94      0.95
#   theta_decentered[165,0,0]     -0.23      0.65     -0.21     -1.45      1.06    -41.48      0.90
#   theta_decentered[166,0,0]      0.12      0.79      0.12     -1.54      1.48    166.39      0.90
#   theta_decentered[167,0,0]      0.00      1.24      0.01     -2.27      2.38   -623.46      0.90
#   theta_decentered[168,0,0]      0.06      1.07      0.27     -1.48      1.37     22.50      0.93
#   theta_decentered[169,0,0]     -0.10      0.83     -0.21     -1.04      0.92     63.28      0.90
#   theta_decentered[170,0,0]      0.39      0.57      0.55     -0.61      1.22     29.44      0.94
#   theta_decentered[171,0,0]     -0.26      1.29     -0.38     -1.92      1.51     98.66      1.00
#   theta_decentered[172,0,0]     -0.63      1.21     -0.78     -1.96      1.56    144.96      0.89
#   theta_decentered[173,0,0]     -0.22      1.50     -0.38     -2.22      2.22     65.98      0.91
#   theta_decentered[174,0,0]      0.01      0.40      0.10     -0.81      0.55     17.55      0.92
#   theta_decentered[175,0,0]     -0.05      0.89     -0.22     -1.15      1.00    156.58      0.93
#   theta_decentered[176,0,0]     -0.20      1.00     -0.23     -1.60      0.97    -25.43      0.94
#   theta_decentered[177,0,0]     -0.19      1.51     -0.38     -2.81      2.56    -87.95      0.90
#   theta_decentered[178,0,0]     -0.13      1.44     -0.07     -1.85      1.96     29.93      0.92
#   theta_decentered[179,0,0]      0.08      0.75     -0.06     -1.05      1.17     37.74      0.96
#   theta_decentered[180,0,0]     -0.34      1.29     -0.79     -2.08      2.13     38.37      0.90
#   theta_decentered[181,0,0]     -0.07      1.69     -0.12     -2.41      2.42     33.32      0.93
#   theta_decentered[182,0,0]      0.10      1.46      0.09     -1.47      1.65   -892.90      0.93
#   theta_decentered[183,0,0]     -0.17      0.99     -0.70     -1.26      1.36     26.75      0.90
#   theta_decentered[184,0,0]      0.02      0.72      0.02     -1.13      1.48     34.26      0.91
#   theta_decentered[185,0,0]     -0.01      0.97      0.03     -1.40      1.43    154.45      0.90
#   theta_decentered[186,0,0]     -0.12      1.26     -0.06     -2.46      2.40   -147.28      0.90
#   theta_decentered[187,0,0]     -0.09      0.55      0.04     -0.88      0.89     25.11      0.94
#   theta_decentered[188,0,0]      0.03      0.90      0.16     -1.82      1.61    177.94      0.91
#   theta_decentered[189,0,0]      0.17      0.89      0.38     -1.27      1.33     37.16      0.90
#   theta_decentered[190,0,0]      0.11      0.46      0.12     -0.70      0.95     46.52      0.90
#   theta_decentered[191,0,0]      0.10      0.56      0.07     -0.86      0.93     22.54      0.95
#   theta_decentered[192,0,0]      0.04      0.47     -0.02     -0.86      1.04     49.94      0.89
#   theta_decentered[193,0,0]      0.08      0.71      0.17     -1.44      1.39   2284.96      0.90
#   theta_decentered[194,0,0]      0.19      0.79      0.19     -0.95      1.18     24.77      0.92
#   theta_decentered[195,0,0]      0.13      0.54      0.16     -0.70      1.11     16.99      1.01
#   theta_decentered[196,0,0]      0.06      1.22      0.06     -1.32      1.45     26.03      0.93
#   theta_decentered[197,0,0]      0.05      0.76      0.06     -1.15      1.41    -53.34      0.90
#   theta_decentered[198,0,0]     -0.13      1.39     -0.13     -2.21      1.57    317.45      0.92
#   theta_decentered[199,0,0]     -0.03      2.58     -0.09     -3.04      3.17     36.09      0.94
#   theta_decentered[200,0,0]      0.15      0.72      0.28     -0.82      0.89     42.26      0.90
#   theta_decentered[201,0,0]      0.07      0.81      0.04     -1.52      1.42   -122.96      0.92
#   theta_decentered[202,0,0]     -0.26      0.86     -0.36     -1.58      1.56     17.91      0.95
#   theta_decentered[203,0,0]      0.00      1.50      0.09     -1.72      1.66     53.09      0.94
#   theta_decentered[204,0,0]     -0.11      0.83     -0.01     -1.32      1.22     25.70      0.92
#   theta_decentered[205,0,0]     -0.00      0.37     -0.02     -0.58      0.62     34.21      0.90
#   theta_decentered[206,0,0]     -0.22      0.65     -0.18     -1.39      0.71     16.20      0.92
#   theta_decentered[207,0,0]      0.18      1.32      0.20     -1.87      2.17     29.18      0.90
#   theta_decentered[208,0,0]      0.04      1.27     -0.05     -1.41      1.43     62.64      0.93
#   theta_decentered[209,0,0]     -0.59      1.19     -0.84     -2.25      2.35     16.42      0.98
#   theta_decentered[210,0,0]     -0.11      1.09     -0.23     -1.59      1.48     27.02      0.90
#   theta_decentered[211,0,0]      0.09      1.02      0.19     -1.22      1.13     68.22      0.92
#   theta_decentered[212,0,0]      0.07      0.46      0.05     -0.55      0.78     70.00      0.93
#   theta_decentered[213,0,0]     -0.22      1.47     -0.09     -2.42      1.71     28.39      0.98
#   theta_decentered[214,0,0]      0.13      0.85      0.08     -0.79      1.17     34.44      0.93
#   theta_decentered[215,0,0]      0.11      1.69      0.02     -2.10      2.12     39.45      0.92
#   theta_decentered[216,0,0]      0.12      1.47      0.05     -1.75      1.86     54.19      0.93
#   theta_decentered[217,0,0]      0.12      0.84      0.10     -1.18      1.20     26.98      0.93
#   theta_decentered[218,0,0]     -0.02      1.25      0.01     -1.60      1.63    135.25      0.96
#   theta_decentered[219,0,0]      0.22      0.66      0.34     -0.90      0.96    194.26      0.89
#   theta_decentered[220,0,0]     -0.04      1.25      0.08     -2.00      1.77    -39.35      0.91
#   theta_decentered[221,0,0]      0.11      0.92      0.09     -1.28      1.48   -970.74      1.00
#   theta_decentered[222,0,0]      0.18      0.61      0.19     -0.80      1.03     98.21      0.90
#   theta_decentered[223,0,0]     -0.02      1.01     -0.03     -1.20      1.07     31.54      0.94
#   theta_decentered[224,0,0]     -0.03      1.19      0.04     -1.67      1.70     36.47      0.93
#   theta_decentered[225,0,0]     -0.04      1.05      0.02     -1.33      1.45     17.12      0.92
#   theta_decentered[226,0,0]      0.04      3.27      0.23     -4.03      4.08     45.27      0.94
#   theta_decentered[227,0,0]     -0.15      1.03     -0.03     -1.61      1.20    107.24      0.91
#   theta_decentered[228,0,0]      0.12      1.02      0.07     -1.20      1.42     35.22      0.92
#   theta_decentered[229,0,0]      0.10      0.79      0.15     -1.67      1.56   -741.28      0.90
#   theta_decentered[230,0,0]      0.08      0.26      0.11     -0.33      0.49    -48.91      0.89
#   theta_decentered[231,0,0]     -0.57      1.22     -0.06     -2.46      1.11     19.72      1.02
#   theta_decentered[232,0,0]      0.05      0.54      0.19     -0.71      0.75   -172.12      0.90
#   theta_decentered[233,0,0]     -0.02      1.10      0.06     -1.59      1.57     22.64      0.95
#   theta_decentered[234,0,0]      0.21      0.90      0.26     -1.52      1.54     56.46      0.91
#   theta_decentered[235,0,0]      0.09      0.57     -0.03     -0.99      1.07     11.23      0.95
#   theta_decentered[236,0,0]      0.07      1.17     -0.08     -1.77      1.77     51.78      0.94
#   theta_decentered[237,0,0]      0.04      0.72      0.10     -1.28      1.20    -36.40      0.90
#   theta_decentered[238,0,0]      0.04      1.05     -0.04     -1.42      1.45     80.12      0.94
#   theta_decentered[239,0,0]      0.11      0.45      0.18     -0.64      0.69    -51.73      0.90
#   theta_decentered[240,0,0]      0.12      1.14      0.11     -1.33      2.16     20.55      0.94
#   theta_decentered[241,0,0]      0.11      0.52      0.32     -0.64      0.72    -31.32      0.89
#   theta_decentered[242,0,0]     -0.05      1.62     -0.07     -2.27      2.39    404.24      0.92
#   theta_decentered[243,0,0]      0.03      1.16      0.01     -1.16      1.41     23.23      0.93
#   theta_decentered[244,0,0]     -0.06      0.37     -0.09     -0.56      0.42   1338.22      0.89
#   theta_decentered[245,0,0]     -0.24      0.78     -0.10     -1.28      1.15     39.81      1.03
#   theta_decentered[246,0,0]      0.16      1.44      0.02     -2.34      2.63     23.36      0.93
#   theta_decentered[247,0,0]     -0.01      0.57      0.10     -0.80      0.80   -358.78      0.94
#   theta_decentered[248,0,0]     -0.15      0.49     -0.14     -0.94      0.76     16.94      1.09
#   theta_decentered[249,0,0]      0.12      1.32      0.03     -1.86      1.74     31.25      0.97
#   theta_decentered[250,0,0]     -0.01      0.66      0.00     -0.84      0.94    -30.47      0.97
#   theta_decentered[251,0,0]      0.11      0.61      0.29     -0.77      0.85     24.32      0.99
#   theta_decentered[252,0,0]      0.31      0.75      0.14     -1.07      1.49     23.51      1.04
#   theta_decentered[253,0,0]     -0.07      1.07     -0.10     -2.05      1.74     34.73      0.90
#   theta_decentered[254,0,0]      0.19      0.67      0.05     -0.88      1.22     15.14      0.97
#   theta_decentered[255,0,0]      0.09      0.61      0.27     -0.99      1.14     30.63      0.90
#   theta_decentered[256,0,0]      0.08      0.88      0.00     -1.33      1.35     50.45      0.93
#   theta_decentered[257,0,0]     -0.04      0.54     -0.13     -0.88      1.00     22.98      0.91
#   theta_decentered[258,0,0]     -0.47      0.92     -0.12     -2.04      0.69     33.63      0.90
#   theta_decentered[259,0,0]     -0.05      1.10     -0.14     -1.38      1.42     65.48      0.91
#   theta_decentered[260,0,0]      0.13      0.58      0.05     -0.81      0.97   2881.00      0.90
#   theta_decentered[261,0,0]      0.13      0.69      0.11     -0.78      1.11   -328.37      0.91
#   theta_decentered[262,0,0]     -0.03      1.47     -0.01     -1.94      1.98     39.03      0.93
#   theta_decentered[263,0,0]      0.09      1.00      0.13     -1.08      1.54     48.04      0.98
#   theta_decentered[264,0,0]     -0.13      1.69      0.03     -2.53      2.38     28.28      0.91
#   theta_decentered[265,0,0]      0.22      0.71      0.23     -1.23      1.33     18.18      0.90
#   theta_decentered[266,0,0]     -0.06      0.49      0.04     -0.82      0.65     11.05      1.13
#   theta_decentered[267,0,0]      0.16      1.32      0.09     -1.86      2.00     29.09      0.91
#   theta_decentered[268,0,0]      0.06      0.41      0.20     -0.66      0.66     41.95      0.90
#   theta_decentered[269,0,0]     -0.04      0.31     -0.04     -0.66      0.37     59.23      0.90
#   theta_decentered[270,0,0]      0.13      1.40      0.19     -1.47      1.93   -178.00      0.97
#   theta_decentered[271,0,0]      0.04      0.20      0.04     -0.28      0.47     36.02      0.91
#   theta_decentered[272,0,0]     -0.15      0.50     -0.17     -0.99      0.48     33.51      0.90
#   theta_decentered[273,0,0]      0.18      0.65      0.13     -0.98      1.16     11.26      0.94
#   theta_decentered[274,0,0]     -0.15      0.80     -0.12     -1.25      1.03     23.70      0.90
#   theta_decentered[275,0,0]      0.15      1.66      0.08     -2.13      2.27     74.71      0.94
#   theta_decentered[276,0,0]     -0.04      1.52      0.01     -1.89      1.84     46.36      0.96
#   theta_decentered[277,0,0]      0.06      1.00      0.00     -1.30      1.19    184.64      0.92
#   theta_decentered[278,0,0]      0.04      0.38      0.09     -0.48      0.51    -32.19      0.94
#   theta_decentered[279,0,0]      0.11      0.48      0.13     -0.65      0.80    104.67      0.89
#   theta_decentered[280,0,0]     -0.00      0.60     -0.13     -1.03      1.15     52.14      0.90
#   theta_decentered[281,0,0]     -0.03      1.24     -0.12     -2.05      2.04     31.28      0.93
#   theta_decentered[282,0,0]     -0.24      0.48     -0.32     -1.17      0.48     21.49      0.95
#   theta_decentered[283,0,0]     -0.17      0.87     -0.35     -1.25      0.85     35.71      0.90
#   theta_decentered[284,0,0]      0.00      0.86     -0.01     -1.24      1.23    164.16      0.94
#   theta_decentered[285,0,0]      0.06      1.62      0.07     -1.76      1.96     40.51      0.93
#   theta_decentered[286,0,0]      0.08      1.27      0.12     -2.45      2.43     51.65      0.90
#   theta_decentered[287,0,0]     -0.11      1.35      0.07     -2.05      1.91    -69.70      0.91
#   theta_decentered[288,0,0]     -0.08      0.54      0.03     -1.26      0.70     15.51      0.96
#   theta_decentered[289,0,0]      0.04      0.42     -0.07     -0.48      0.69     10.10      0.93
#   theta_decentered[290,0,0]     -0.15      1.28      0.09     -1.79      1.31     29.80      0.90
#   theta_decentered[291,0,0]      0.39      0.44      0.45     -0.68      0.89      9.29      1.10
#   theta_decentered[292,0,0]     -0.59      1.96     -0.11     -3.08      2.38     30.29      1.00
#   theta_decentered[293,0,0]      0.13      1.09      0.10     -1.15      1.44     49.10      0.96
#   theta_decentered[294,0,0]      0.18      1.91      0.01     -2.47      2.50   -191.52      0.92
#   theta_decentered[295,0,0]      0.19      0.86      0.20     -1.45      1.45 46281975.17      0.92
#   theta_decentered[296,0,0]     -0.23      0.61     -0.10     -1.24      0.56     18.39      0.95
#   theta_decentered[297,0,0]      0.08      1.11      0.30     -1.64      1.69    -22.90      0.90
#   theta_decentered[298,0,0]      0.19      0.87      0.29     -1.35      1.61     18.41      0.93
#   theta_decentered[299,0,0]      0.07      0.72      0.21     -1.43      1.40    190.52      0.89
#   theta_decentered[300,0,0]     -0.05      2.26     -0.07     -2.43      2.49     24.88      0.93
#   theta_decentered[301,0,0]     -0.07      1.25     -0.02     -1.86      1.50     25.46      0.96
#   theta_decentered[302,0,0]      0.03      1.43     -0.23     -1.86      1.98     32.56      0.95
#   theta_decentered[303,0,0]      0.07      1.01      0.11     -1.28      1.42     49.20      0.91
#   theta_decentered[304,0,0]     -0.05      1.33     -0.01     -1.72      1.60     39.24      0.95
#   theta_decentered[305,0,0]      0.01      1.41     -0.00     -2.29      2.22     49.43      0.91
#   theta_decentered[306,0,0]     -0.06      0.63     -0.05     -1.01      1.10    -45.44      0.91
#   theta_decentered[307,0,0]      0.00      0.61     -0.09     -1.06      1.20     53.81      0.90
#   theta_decentered[308,0,0]     -0.05      1.40      0.04     -1.91      1.71    175.49      0.94
#   theta_decentered[309,0,0]     -0.06      0.63      0.05     -0.89      0.82   -193.06      0.92
#   theta_decentered[310,0,0]      0.19      1.12      0.16     -1.90      1.92     33.51      0.90
#   theta_decentered[311,0,0]      0.04      0.67      0.14     -1.02      0.94   -204.35      0.90
#   theta_decentered[312,0,0]      0.11      0.82      0.14     -1.23      1.56    757.01      0.89
#   theta_decentered[313,0,0]     -0.00      0.64      0.28     -1.25      0.69     67.63      0.94
#   theta_decentered[314,0,0]      0.02      0.51      0.02     -0.76      0.61    186.40      0.94
#   theta_decentered[315,0,0]     -0.00      1.67      0.07     -1.83      1.78     86.91      0.94
#   theta_decentered[316,0,0]     -0.03      1.35      0.02     -1.61      1.72     31.89      0.93
#   theta_decentered[317,0,0]     -0.07      0.71     -0.20     -1.17      1.20     37.99      0.90
#   theta_decentered[318,0,0]     -0.38      1.31     -0.54     -1.74      1.67     28.30      0.90
#   theta_decentered[319,0,0]      0.03      0.66      0.09     -1.16      1.18   -126.42      0.90
#   theta_decentered[320,0,0]     -0.02      0.88      0.14     -1.26      1.33     58.13      0.93
#   theta_decentered[321,0,0]      0.25      1.14      0.09     -1.20      1.92    133.84      0.90
#   theta_decentered[322,0,0]     -0.36      0.95     -0.70     -1.76      1.05     88.50      0.92
#   theta_decentered[323,0,0]     -0.09      1.25      0.07     -1.59      1.63   -159.39      0.93
#   theta_decentered[324,0,0]     -0.08      0.45     -0.15     -0.80      0.63     18.89      0.90
#   theta_decentered[325,0,0]      0.16      0.59      0.45     -0.74      0.76     22.39      0.89
#   theta_decentered[326,0,0]      0.03      0.33      0.01     -0.54      0.60     33.76      0.90
#   theta_decentered[327,0,0]     -0.58      0.65     -0.47     -1.46      0.51      6.92      1.22
#   theta_decentered[328,0,0]      0.05      0.94      0.05     -1.38      1.18    141.27      0.92
#   theta_decentered[329,0,0]      0.06      1.10      0.27     -1.49      1.49     22.98      0.91
#   theta_decentered[330,0,0]     -0.11      1.92     -0.41     -2.40      2.24     25.23      0.97
#   theta_decentered[331,0,0]      0.08      0.72     -0.03     -1.15      1.28   -502.38      0.94
#   theta_decentered[332,0,0]     -0.15      1.23     -0.33     -1.77      1.78     82.80      0.94
#   theta_decentered[333,0,0]      0.22      1.02      0.80     -1.27      1.29    -28.47      0.90
#   theta_decentered[334,0,0]      0.02      2.06     -0.05     -2.16      2.25     66.98      0.94
#   theta_decentered[335,0,0]     -0.54      1.40      0.05     -2.54      0.92     78.80      0.90
#   theta_decentered[336,0,0]     -0.11      0.94     -0.32     -1.21      1.14     71.26      0.91
#   theta_decentered[337,0,0]     -0.56      0.64     -0.52     -1.54      0.31     14.27      1.25
#   theta_decentered[338,0,0]      0.20      1.08      0.11     -1.40      1.74     47.01      0.94
#   theta_decentered[339,0,0]     -0.05      0.89      0.05     -1.39      0.99    -55.77      0.90
#   theta_decentered[340,0,0]     -0.05      0.47     -0.03     -0.78      0.87     29.32      0.90
#   theta_decentered[341,0,0]      0.04      0.51      0.05     -0.92      1.02   -189.52      0.90
#   theta_decentered[342,0,0]     -0.49      1.51     -0.11     -2.47      1.28  -2469.18      0.90
#   theta_decentered[343,0,0]     -0.03      0.19     -0.02     -0.26      0.24     23.71      0.94
#   theta_decentered[344,0,0]      0.02      0.44      0.10     -0.81      0.62     20.30      1.10
#   theta_decentered[345,0,0]      0.07      3.00      0.06     -3.30      3.45     41.30      0.95
#   theta_decentered[346,0,0]      0.08      1.00      0.05     -1.61      1.70     45.19      0.93
#   theta_decentered[347,0,0]      0.01      0.62     -0.02     -0.90      0.74   -102.53      0.96
#   theta_decentered[348,0,0]      0.01      0.54      0.05     -0.79      0.97     20.63      0.96
#   theta_decentered[349,0,0]     -0.25      1.08     -0.03     -1.76      0.91     19.71      1.05
#   theta_decentered[350,0,0]      0.03      0.73      0.09     -1.34      1.05    -53.07      0.94
#   theta_decentered[351,0,0]      0.05      1.61     -0.03     -1.68      1.85     45.40      0.94
#   theta_decentered[352,0,0]      0.12      0.48      0.28     -0.65      0.89    167.47      0.90
#   theta_decentered[353,0,0]      0.26      0.54      0.36     -0.53      0.90     23.52      0.89
#   theta_decentered[354,0,0]      0.02      0.36      0.04     -0.69      0.66    177.32      0.90
#   theta_decentered[355,0,0]      0.20      1.20      0.14     -1.11      2.04     38.47      0.98
#   theta_decentered[356,0,0]     -0.02      0.48      0.03     -0.69      0.67   -516.27      1.02
#   theta_decentered[357,0,0]      0.09      0.65     -0.02     -0.82      1.15    288.92      0.96
#   theta_decentered[358,0,0]      0.16      1.43      0.24     -2.57      2.51     35.33      0.90
#   theta_decentered[359,0,0]      0.01      0.55      0.05     -0.87      0.69     28.52      0.90
#   theta_decentered[360,0,0]     -0.37      1.11     -0.49     -1.79      1.71     34.13      0.93
#   theta_decentered[361,0,0]     -0.18      1.42     -0.02     -1.80      1.79     33.12      0.91
#   theta_decentered[362,0,0]     -0.02      2.05     -0.01     -2.53      2.64     36.64      0.96
#   theta_decentered[363,0,0]     -0.01      0.72      0.07     -1.06      0.90     49.18      0.98
#   theta_decentered[364,0,0]     -0.08      0.76     -0.18     -1.32      0.90     24.10      0.90
#   theta_decentered[365,0,0]      0.05      0.66      0.09     -1.13      1.28     24.06      0.92
#   theta_decentered[366,0,0]      0.07      0.78      0.06     -1.22      1.36     23.28      0.90
#   theta_decentered[367,0,0]     -0.08      0.87      0.00     -1.33      0.93     73.86      0.92
#   theta_decentered[368,0,0]      0.06      1.06      0.03     -1.31      1.24     26.66      0.92
#   theta_decentered[369,0,0]      0.10      0.32      0.14     -0.50      0.51    114.31      0.90
#   theta_decentered[370,0,0]      0.12      0.61      0.00     -0.87      1.22     11.76      0.94
#   theta_decentered[371,0,0]      0.05      0.54      0.07     -0.99      1.14   2530.04      0.89
#   theta_decentered[372,0,0]      0.02      0.99      0.12     -1.64      1.70     28.45      0.92
#   theta_decentered[373,0,0]     -0.06      0.94     -0.01     -1.24      1.08    104.28      0.94
#   theta_decentered[374,0,0]     -0.09      1.34     -0.06     -1.73      1.70     51.64      0.95
#   theta_decentered[375,0,0]      0.01      1.66      0.00     -2.51      2.32     33.47      0.90
#   theta_decentered[376,0,0]      0.03      1.48      0.04     -1.58      1.59   -188.68      0.93
#   theta_decentered[377,0,0]     -0.02      0.36      0.01     -0.54      0.54     13.85      1.05
#   theta_decentered[378,0,0]     -0.06      1.60     -0.07     -2.15      2.07     26.00      0.91
#   theta_decentered[379,0,0]      0.09      1.06      0.17     -1.13      1.26     24.91      0.91
#   theta_decentered[380,0,0]     -0.20      0.52     -0.27     -0.76      0.85      6.73      1.17
#   theta_decentered[381,0,0]      0.04      0.90      0.04     -1.22      1.27     53.57      0.91
#   theta_decentered[382,0,0]     -0.07      1.68     -0.01     -2.01      2.08     27.40      0.93
#   theta_decentered[383,0,0]      0.06      0.66     -0.15     -0.85      1.29     25.82      0.93
#   theta_decentered[384,0,0]      0.06      0.42      0.12     -0.77      0.85    189.64      0.89
#   theta_decentered[385,0,0]      0.16      1.93      0.14     -2.15      2.52     38.12      0.96
#   theta_decentered[386,0,0]      0.02      0.87      0.07     -1.01      0.98     48.28      0.91
#   theta_decentered[387,0,0]     -0.10      0.68     -0.12     -1.20      1.23     50.75      0.90
#   theta_decentered[388,0,0]      0.06      0.64      0.08     -0.82      0.88    113.21      0.95
#   theta_decentered[389,0,0]      0.14      1.85      0.07     -1.88      2.66     83.31      0.96
#   theta_decentered[390,0,0]     -0.15      1.53     -0.02     -2.15      2.40     52.26      0.92
#   theta_decentered[391,0,0]      0.04      1.77      0.11     -2.30      2.20     25.55      0.94
#   theta_decentered[392,0,0]      0.02      0.99     -0.11     -1.31      1.51     24.29      0.94
#   theta_decentered[393,0,0]     -0.35      0.72     -0.20     -1.54      0.80      7.19      1.12
#   theta_decentered[394,0,0]     -0.20      2.01      0.02     -2.34      2.14     26.84      0.95
#   theta_decentered[395,0,0]     -0.07      0.82      0.03     -1.35      1.28     41.93      0.91
#   theta_decentered[396,0,0]     -0.07      1.71     -0.08     -2.12      2.49     48.03      0.95
#   theta_decentered[397,0,0]     -0.14      1.19     -0.17     -2.32      2.36     43.41      0.92
#   theta_decentered[398,0,0]     -0.10      0.85     -0.04     -1.29      1.55     51.48      0.95
#   theta_decentered[399,0,0]      0.02      0.74      0.04     -1.19      1.14     38.14      0.89
#   theta_decentered[400,0,0]      0.03      0.43      0.07     -0.52      0.54    -20.85      0.89
#   theta_decentered[401,0,0]     -0.10      0.50     -0.37     -0.69      0.63    -82.29      0.90
#   theta_decentered[402,0,0]     -0.01      1.59      0.04     -1.97      2.14     24.39      0.93
#   theta_decentered[403,0,0]      0.05      1.68      0.00     -2.18      2.47     49.23      0.92
#   theta_decentered[404,0,0]     -0.07      0.56     -0.10     -0.84      0.89     38.75      0.90
#   theta_decentered[405,0,0]      0.01      0.87     -0.04     -1.16      1.41     23.08      0.93
#   theta_decentered[406,0,0]      0.04      1.07      0.10     -1.31      1.61     65.39      0.93
#   theta_decentered[407,0,0]     -0.05      0.66     -0.04     -0.97      0.91   -755.32      0.95
#   theta_decentered[408,0,0]     -0.02      0.76     -0.12     -1.15      1.36    261.27      0.91
#   theta_decentered[409,0,0]     -0.08      1.58     -0.07     -2.17      2.24    134.90      0.96
#   theta_decentered[410,0,0]     -0.03      1.02      0.06     -1.58      1.18     67.43      0.91
#   theta_decentered[411,0,0]      0.03      0.97      0.06     -1.50      1.31     24.73      0.90
#   theta_decentered[412,0,0]      0.09      0.94      0.01     -1.23      1.50     37.23      0.95
#   theta_decentered[413,0,0]      0.01      1.13     -0.03     -1.25      1.39     45.47      0.91
#   theta_decentered[414,0,0]      0.00      0.81     -0.00     -1.51      1.73    471.53      0.89
#   theta_decentered[415,0,0]     -0.57      1.10     -0.68     -1.75      1.24     30.65      0.89
#   theta_decentered[416,0,0]      0.08      0.79      0.03     -1.03      1.13     36.38      0.94
#   theta_decentered[417,0,0]      0.01      0.26      0.02     -0.40      0.34     75.37      0.90
#   theta_decentered[418,0,0]      0.17      0.58      0.12     -0.49      1.40     12.93      0.97
#   theta_decentered[419,0,0]     -0.17      1.25     -0.07     -1.80      1.77    157.03      0.95
#   theta_decentered[420,0,0]     -0.18      0.42     -0.02     -1.00      0.30     38.51      0.92
#   theta_decentered[421,0,0]      0.17      1.47      0.19     -2.45      2.48     63.99      0.90
#   theta_decentered[422,0,0]     -0.12      1.71     -0.04     -2.39      2.36     93.24      0.95
#   theta_decentered[423,0,0]     -0.23      1.03     -0.01     -1.90      1.79     34.29      0.94
#   theta_decentered[424,0,0]     -0.05      1.18      0.05     -1.83      1.24     94.99      0.91
#   theta_decentered[425,0,0]      0.12      0.89      0.37     -1.20      1.15    -20.27      0.90
#   theta_decentered[426,0,0]     -0.08      0.64     -0.25     -0.83      0.84     67.37      0.99
#   theta_decentered[427,0,0]     -0.02      0.14     -0.04     -0.28      0.21     53.74      0.89
#   theta_decentered[428,0,0]      0.01      0.94      0.04     -1.84      1.93     35.85      0.91
#   theta_decentered[429,0,0]     -0.23      0.51     -0.38     -0.83      0.71     20.96      0.90
#   theta_decentered[430,0,0]     -0.12      0.80     -0.13     -1.23      1.31     75.31      0.93
#   theta_decentered[431,0,0]     -0.08      0.70     -0.18     -1.51      1.10     55.14      0.90
#   theta_decentered[432,0,0]      0.02      1.48      0.08     -1.74      1.90     51.76      0.94
#   theta_decentered[433,0,0]     -0.04      0.58     -0.05     -1.09      0.77     42.01      0.93
#   theta_decentered[434,0,0]      0.08      1.56     -0.03     -2.20      2.12 -275318416.41      0.93
#   theta_decentered[435,0,0]     -0.15      1.03     -0.26     -1.44      1.23    -86.11      0.93
#   theta_decentered[436,0,0]      0.02      0.76      0.04     -1.51      1.61   -402.07      0.89
#   theta_decentered[437,0,0]     -0.15      1.84     -0.20     -2.35      2.09    121.94      0.91
#   theta_decentered[438,0,0]     -0.01      0.89     -0.02     -1.55      1.13     46.66      0.92
#   theta_decentered[439,0,0]      0.08      0.26      0.03     -0.30      0.43     15.19      0.92
#   theta_decentered[440,0,0]      0.02      0.71      0.13     -1.17      1.08     84.38      0.95
#   theta_decentered[441,0,0]      0.29      0.52      0.50     -0.52      0.98     17.99      0.95
#   theta_decentered[442,0,0]     -0.25      0.78     -0.07     -1.49      0.78     30.04      0.90
#   theta_decentered[443,0,0]     -0.01      0.82     -0.21     -1.47      1.56     40.45      0.90
#   theta_decentered[444,0,0]     -0.05      0.21     -0.04     -0.36      0.32     12.09      0.90
#   theta_decentered[445,0,0]     -0.43      0.49     -0.34     -1.24      0.27      9.89      1.01
#   theta_decentered[446,0,0]      0.03      0.40     -0.00     -0.51      0.81     56.05      0.91
#   theta_decentered[447,0,0]     -0.01      0.90      0.09     -1.91      1.32     37.59      0.90
#   theta_decentered[448,0,0]      0.24      1.12      0.63     -1.50      1.69     26.75      0.90
#   theta_decentered[449,0,0]      0.06      0.66      0.13     -1.19      1.31     22.32      0.90
#   theta_decentered[450,0,0]      0.06      1.31     -0.02     -1.61      1.74   -412.67      0.96
#   theta_decentered[451,0,0]     -0.09      1.01     -0.31     -1.22      1.52   -340.59      0.91
#   theta_decentered[452,0,0]     -0.07      0.91     -0.07     -1.64      1.36     33.14      0.96
#   theta_decentered[453,0,0]     -0.23      0.96     -0.03     -1.96      1.57     13.64      0.98
#   theta_decentered[454,0,0]      0.03      0.98     -0.03     -1.75      1.88     37.32      0.90
#   theta_decentered[455,0,0]      0.01      0.87     -0.06     -1.12      1.20    130.81      0.95
#   theta_decentered[456,0,0]      0.06      0.38      0.09     -0.52      0.57     30.31      0.91
#   theta_decentered[457,0,0]     -0.04      2.53     -0.03     -3.00      2.91     56.10      0.94
#   theta_decentered[458,0,0]      0.14      0.58      0.26     -0.74      0.95     38.52      0.90
#   theta_decentered[459,0,0]     -0.09      0.25     -0.15     -0.40      0.32     19.87      1.07
#   theta_decentered[460,0,0]     -0.11      0.34     -0.11     -0.61      0.52     24.23      0.90
#   theta_decentered[461,0,0]     -0.07      0.37     -0.03     -0.76      0.41     30.15      0.90
#   theta_decentered[462,0,0]      0.13      0.49      0.17     -0.74      0.93     50.02      0.90
#   theta_decentered[463,0,0]      0.05      0.46      0.07     -0.63      0.63    -38.63      0.90
#   theta_decentered[464,0,0]      0.22      1.14      0.46     -1.51      1.59     48.50      0.91
#   theta_decentered[465,0,0]     -0.09      0.51     -0.03     -0.95      1.00     21.36      0.96
#   theta_decentered[466,0,0]      0.08      2.11      0.05     -2.51      2.71     37.47      0.94
#   theta_decentered[467,0,0]      0.07      1.09      0.11     -1.29      1.30     85.32      0.93
#   theta_decentered[468,0,0]     -0.05      0.70     -0.14     -0.90      1.18    -63.55      0.90
#   theta_decentered[469,0,0]     -0.07      0.27     -0.11     -0.36      0.33     25.54      0.91
#   theta_decentered[470,0,0]      0.00      1.52      0.18     -1.91      1.89     50.60      0.99
#   theta_decentered[471,0,0]     -0.03      0.99     -0.01     -1.71      1.60  -2072.40      0.90
#   theta_decentered[472,0,0]     -0.09      1.31     -0.12     -1.62      1.82     85.60      0.93
#   theta_decentered[473,0,0]      0.01      0.79     -0.08     -1.04      1.08     35.15      0.91
#   theta_decentered[474,0,0]      0.02      1.14      0.07     -1.30      1.65     26.15      0.92
#   theta_decentered[475,0,0]      0.00      1.08      0.04     -1.61      1.10     26.01      0.90
#   theta_decentered[476,0,0]     -0.59      1.40     -0.16     -2.85      1.54     28.35      1.09
#   theta_decentered[477,0,0]      0.08      1.70      0.07     -1.85      1.96     50.07      0.95
# ...
# theta_decentered[23958,0,0]      0.05      0.87     -0.09     -1.32      1.43 69050921.16      0.95
# theta_decentered[23959,0,0]     -0.13      0.65     -0.28     -0.94      0.91    -65.71      0.90
# theta_decentered[23960,0,0]     -0.02      0.77      0.00     -1.19      1.11     95.25      0.90
# theta_decentered[23961,0,0]     -0.01      0.81     -0.11     -1.35      1.38    -34.15      0.90
# theta_decentered[23962,0,0]     -0.08      0.82     -0.06     -1.29      1.28     88.29      0.96
# theta_decentered[23963,0,0]     -0.10      1.39     -0.07     -2.12      1.77    107.72      0.94
# theta_decentered[23964,0,0]     -0.03      0.60      0.06     -0.94      0.85     28.53      0.93
# theta_decentered[23965,0,0]      0.08      0.48      0.25     -0.59      0.67    -23.91      0.93
# theta_decentered[23966,0,0]      0.04      0.73      0.12     -1.08      1.10     28.59      0.90
# theta_decentered[23967,0,0]      0.09      1.30      0.12     -2.12      2.27    -39.44      0.90
# theta_decentered[23968,0,0]     -0.16      2.65      0.05     -3.37      3.41     39.04      0.93
# theta_decentered[23969,0,0]     -0.08      0.80      0.08     -1.26      0.91     22.94      0.92
# theta_decentered[23970,0,0]     -0.08      0.29     -0.08     -0.52      0.36     39.97      0.92
# theta_decentered[23971,0,0]      0.08      0.49      0.17     -0.59      0.80     26.58      0.91
# theta_decentered[23972,0,0]      0.07      0.50      0.05     -0.67      0.76   -247.22      0.93
# theta_decentered[23973,0,0]      0.04      0.53     -0.05     -0.72      0.80     32.03      0.94
# theta_decentered[23974,0,0]     -0.03      0.45     -0.12     -0.65      0.80     21.61      0.90
# theta_decentered[23975,0,0]     -0.05      1.00     -0.15     -1.65      1.78     42.62      0.90
# theta_decentered[23976,0,0]      0.01      0.42     -0.04     -0.80      0.79     15.86      0.91
# theta_decentered[23977,0,0]     -0.10      0.30     -0.04     -0.69      0.32      8.44      1.01
# theta_decentered[23978,0,0]      0.01      1.29      0.07     -1.60      1.60     95.74      0.96
# theta_decentered[23979,0,0]     -0.10      0.48     -0.12     -0.86      0.56     27.27      0.98
# theta_decentered[23980,0,0]     -0.09      1.02     -0.07     -1.25      1.14    158.68      0.92
# theta_decentered[23981,0,0]     -0.03      0.58     -0.17     -0.88      1.02     27.24      0.90
# theta_decentered[23982,0,0]     -0.09      1.68      0.03     -2.18      1.76     32.83      0.94
# theta_decentered[23983,0,0]      0.07      0.38      0.17     -0.54      0.61     23.60      0.90
# theta_decentered[23984,0,0]      0.00      0.62     -0.09     -1.14      1.09    -70.77      0.91
# theta_decentered[23985,0,0]     -0.03      0.68     -0.04     -0.74      0.72     27.03      0.95
# theta_decentered[23986,0,0]     -0.09      0.62     -0.09     -0.95      0.69     32.80      0.94
# theta_decentered[23987,0,0]      0.15      0.92      0.01     -1.28      1.38    125.46      0.90
# theta_decentered[23988,0,0]     -0.06      1.66     -0.08     -1.85      1.92     24.67      0.93
# theta_decentered[23989,0,0]     -0.14      0.43     -0.10     -0.80      0.42     22.09      0.90
# theta_decentered[23990,0,0]      0.04      0.99      0.16     -1.74      1.76     34.12      0.90
# theta_decentered[23991,0,0]      0.25      1.62      0.10     -2.73      2.85     19.93      0.91
# theta_decentered[23992,0,0]      0.12      1.78      0.13     -2.15      2.24     28.36      0.94
# theta_decentered[23993,0,0]     -0.15      0.84     -0.22     -1.77      0.93    122.16      0.94
# theta_decentered[23994,0,0]     -0.11      0.82     -0.04     -1.74      1.44    -64.92      0.89
# theta_decentered[23995,0,0]     -0.05      0.63     -0.19     -1.09      1.09     35.82      0.90
# theta_decentered[23996,0,0]     -0.04      1.41      0.00     -1.63      1.37     30.34      0.92
# theta_decentered[23997,0,0]     -0.13      1.20     -0.01     -1.78      1.74   -104.84      0.92
# theta_decentered[23998,0,0]      0.15      0.58      0.06     -0.52      1.45     38.32      0.95
# theta_decentered[23999,0,0]      0.08      0.74     -0.13     -1.02      1.32      9.62      0.98
# theta_decentered[24000,0,0]     -0.08      1.69     -0.01     -2.22      2.23     63.64      0.93
# theta_decentered[24001,0,0]      0.10      0.88     -0.02     -1.25      1.30     81.57      0.93
# theta_decentered[24002,0,0]     -0.16      1.18      0.06     -1.64      1.72    973.04      0.91
# theta_decentered[24003,0,0]     -0.08      1.62     -0.05     -2.42      2.49    106.03      0.91
# theta_decentered[24004,0,0]      0.08      0.88      0.17     -1.26      1.32   -193.10      0.93
# theta_decentered[24005,0,0]      0.16      0.72      0.32     -1.00      1.13    -67.20      0.90
# theta_decentered[24006,0,0]     -0.01      1.49     -0.01     -2.08      1.65     32.88      0.94
# theta_decentered[24007,0,0]      0.13      0.74      0.20     -0.86      1.20     13.91      0.91
# theta_decentered[24008,0,0]     -0.09      0.89     -0.01     -1.19      1.10   -149.61      0.92
# theta_decentered[24009,0,0]     -0.27      0.98     -0.55     -1.20      1.23    -57.87      0.89
# theta_decentered[24010,0,0]      0.06      0.38      0.07     -0.61      0.70     19.54      0.89
# theta_decentered[24011,0,0]     -0.12      0.84     -0.33     -1.26      1.18     28.32      0.89
# theta_decentered[24012,0,0]      0.03      0.99     -0.05     -1.08      1.21     35.77      0.93
# theta_decentered[24013,0,0]      0.07      0.95     -0.02     -1.52      1.51    -63.84      0.91
# theta_decentered[24014,0,0]      0.10      0.62      0.33     -0.82      0.86     25.98      0.91
# theta_decentered[24015,0,0]      0.06      1.11     -0.02     -2.03      2.12     45.79      0.90
# theta_decentered[24016,0,0]     -0.04      0.77     -0.03     -1.47      1.38    -45.49      0.91
# theta_decentered[24017,0,0]      0.05      1.23      0.06     -2.10      2.07     43.52      0.91
# theta_decentered[24018,0,0]     -0.01      1.11     -0.02     -2.14      2.36    -68.54      0.90
# theta_decentered[24019,0,0]      0.10      0.75      0.19     -1.12      0.92     73.09      0.90
# theta_decentered[24020,0,0]     -0.08      0.72     -0.14     -0.91      1.05    -22.33      0.92
# theta_decentered[24021,0,0]      0.10      1.63      0.02     -2.04      2.18     30.02      0.95
# theta_decentered[24022,0,0]      0.10      0.53      0.06     -0.60      0.80     33.97      0.99
# theta_decentered[24023,0,0]      0.06      0.62      0.01     -1.08      1.16     20.32      0.91
# theta_decentered[24024,0,0]      0.06      0.38      0.15     -0.72      0.56     31.83      0.89
# theta_decentered[24025,0,0]      0.04      1.95      0.05     -2.41      2.21     31.21      0.93
# theta_decentered[24026,0,0]      0.13      1.09     -0.02     -1.61      1.60  -1895.21      0.92
# theta_decentered[24027,0,0]      0.10      0.68      0.10     -1.09      1.09   -515.39      0.94
# theta_decentered[24028,0,0]      0.21      0.96      0.13     -1.54      1.58     90.61      0.91
# theta_decentered[24029,0,0]     -0.16      1.90     -0.08     -3.01      2.43    104.33      0.95
# theta_decentered[24030,0,0]      0.08      1.38     -0.03     -1.92      2.19     42.13      0.94
# theta_decentered[24031,0,0]     -0.00      1.05      0.02     -1.23      1.21     27.25      0.93
# theta_decentered[24032,0,0]     -0.06      0.60     -0.27     -1.02      1.10   -225.27      0.89
# theta_decentered[24033,0,0]     -0.15      0.47     -0.24     -0.73      0.74     42.78      0.90
# theta_decentered[24034,0,0]     -0.07      1.18     -0.18     -1.45      1.62     28.01      0.93
# theta_decentered[24035,0,0]     -0.16      1.30     -0.24     -1.89      1.70    -31.56      0.91
# theta_decentered[24036,0,0]      0.05      0.25      0.02     -0.32      0.65     37.48      0.89
# theta_decentered[24037,0,0]     -0.01      0.97      0.07     -1.99      1.86   -320.14      0.89
# theta_decentered[24038,0,0]      0.05      0.90      0.00     -1.60      1.58     36.05      0.91
# theta_decentered[24039,0,0]      0.02      0.20     -0.00     -0.20      0.53     10.78      0.97
# theta_decentered[24040,0,0]     -0.06      0.56     -0.09     -0.71      0.81     32.92      0.91
# theta_decentered[24041,0,0]     -0.12      0.95     -0.09     -1.63      0.91     58.86      0.96
# theta_decentered[24042,0,0]      0.04      1.01      0.28     -1.80      1.86     42.74      0.90
# theta_decentered[24043,0,0]      0.04      1.03      0.05     -1.15      1.26     71.54      0.95
# theta_decentered[24044,0,0]      0.08      1.11     -0.03     -1.60      1.64     32.73      0.90
# theta_decentered[24045,0,0]     -0.08      1.38     -0.02     -1.90      1.96   -108.41      0.95
# theta_decentered[24046,0,0]     -0.03      0.55      0.03     -0.77      0.76    -80.78      0.90
# theta_decentered[24047,0,0]      0.16      0.90      0.35     -1.44      1.43     14.64      0.90
# theta_decentered[24048,0,0]     -0.04      0.77     -0.18     -1.35      1.49     38.48      0.89
# theta_decentered[24049,0,0]     -0.07      0.73     -0.26     -1.13      1.14    -27.32      0.90
# theta_decentered[24050,0,0]      0.10      1.43      0.35     -1.97      1.70    -35.90      0.91
# theta_decentered[24051,0,0]     -0.12      1.11     -0.25     -1.74      1.87    -63.15      0.90
# theta_decentered[24052,0,0]     -0.05      1.24     -0.06     -1.85      1.81     32.43      0.92
# theta_decentered[24053,0,0]      0.10      1.02      0.17     -2.09      2.05   -108.60      0.89
# theta_decentered[24054,0,0]     -0.10      0.51     -0.09     -0.74      0.71     20.93      0.91
# theta_decentered[24055,0,0]     -0.04      1.07     -0.06     -1.44      1.25    114.61      0.91
# theta_decentered[24056,0,0]      0.16      0.67      0.21     -1.05      1.21    195.02      0.92
# theta_decentered[24057,0,0]      0.10      0.65     -0.06     -0.68      1.61     17.96      0.98
# theta_decentered[24058,0,0]      0.10      1.05      0.00     -1.83      2.02     50.79      0.90
# theta_decentered[24059,0,0]      0.02      1.75     -0.08     -2.18      2.13     29.85      0.95
# theta_decentered[24060,0,0]     -0.01      1.39      0.11     -1.92      1.74    135.91      0.95
# theta_decentered[24061,0,0]     -0.03      0.52     -0.06     -1.05      0.96    132.34      0.89
# theta_decentered[24062,0,0]     -0.20      0.95     -0.64     -1.39      1.62     67.11      0.90
# theta_decentered[24063,0,0]     -0.14      0.92     -0.38     -1.32      1.08    -25.34      0.90
# theta_decentered[24064,0,0]     -0.04      1.61     -0.11     -1.89      1.80     45.10      0.93
# theta_decentered[24065,0,0]     -0.29      1.24     -0.80     -1.63      1.56   -170.16      0.90
# theta_decentered[24066,0,0]     -0.08      1.14     -0.30     -1.59      1.65    -53.90      0.92
# theta_decentered[24067,0,0]     -0.01      0.62      0.05     -0.76      0.70     80.72      0.91
# theta_decentered[24068,0,0]     -0.01      0.64      0.06     -1.27      1.13     22.30      0.93
# theta_decentered[24069,0,0]     -0.12      1.12     -0.08     -1.56      1.46    194.76      0.93
# theta_decentered[24070,0,0]      0.02      0.60      0.12     -0.77      1.01     16.20      0.92
# theta_decentered[24071,0,0]     -0.07      0.86     -0.20     -0.94      1.24     28.23      0.90
# theta_decentered[24072,0,0]     -0.01      1.04      0.04     -1.54      1.23  -1459.47      0.90
# theta_decentered[24073,0,0]     -0.01      0.29     -0.01     -0.36      0.33     18.12      0.90
# theta_decentered[24074,0,0]     -0.12      1.23     -0.21     -1.79      1.86     96.21      0.91
# theta_decentered[24075,0,0]     -0.09      0.87      0.01     -1.41      1.42     14.99      0.91
# theta_decentered[24076,0,0]      0.09      0.36      0.09     -0.35      0.87      8.64      1.04
# theta_decentered[24077,0,0]      0.01      0.53      0.01     -0.57      0.83     32.38      0.96
# theta_decentered[24078,0,0]     -0.03      0.92     -0.01     -1.52      1.49     36.67      0.91
# theta_decentered[24079,0,0]     -0.05      1.55      0.12     -2.12      2.07     92.02      0.93
# theta_decentered[24080,0,0]     -0.11      0.52     -0.05     -1.14      0.64     24.62      0.91
# theta_decentered[24081,0,0]      0.06      0.80      0.00     -1.27      1.16     47.57      0.93
# theta_decentered[24082,0,0]     -0.01      0.95     -0.02     -1.42      1.40     28.95      0.91
# theta_decentered[24083,0,0]     -0.07      1.12     -0.10     -2.04      2.29   -356.21      0.93
# theta_decentered[24084,0,0]     -0.08      1.55     -0.13     -1.95      2.05     45.83      0.92
# theta_decentered[24085,0,0]     -0.06      0.64     -0.05     -1.05      1.07     26.31      0.99
# theta_decentered[24086,0,0]     -0.04      1.45     -0.03     -2.10      1.91     45.02      0.92
# theta_decentered[24087,0,0]      0.10      1.05      0.01     -1.46      1.54     26.64      0.93
# theta_decentered[24088,0,0]      0.01      0.47      0.04     -0.68      0.65    129.08      0.97
# theta_decentered[24089,0,0]      0.11      0.57      0.02     -0.76      1.35     52.74      0.95
# theta_decentered[24090,0,0]      0.03      1.08      0.17     -2.00      1.77     35.49      0.91
# theta_decentered[24091,0,0]     -0.05      0.86     -0.12     -1.20      1.26     49.24      0.90
# theta_decentered[24092,0,0]     -0.04      0.58     -0.16     -0.87      1.05     30.53      0.90
# theta_decentered[24093,0,0]      0.06      0.78      0.01     -1.13      1.04     35.91      0.92
# theta_decentered[24094,0,0]     -0.12      1.15     -0.33     -1.45      1.46     20.81      0.90
# theta_decentered[24095,0,0]      0.01      0.53      0.08     -0.95      0.97     44.34      0.89
# theta_decentered[24096,0,0]      0.13      0.60      0.21     -0.62      1.20     18.90      0.89
# theta_decentered[24097,0,0]      0.01      0.38     -0.04     -0.62      0.63   -678.22      0.90
# theta_decentered[24098,0,0]     -0.23      1.13     -0.33     -1.92      1.90     15.99      0.91
# theta_decentered[24099,0,0]      0.13      1.82      0.01     -2.49      2.55     47.16      0.95
# theta_decentered[24100,0,0]     -0.15      0.83     -0.01     -1.25      1.11    630.14      0.94
# theta_decentered[24101,0,0]      0.03      0.88      0.01     -1.37      1.37     33.20      0.90
# theta_decentered[24102,0,0]      0.03      0.98      0.00     -1.30      1.38     27.16      0.94
# theta_decentered[24103,0,0]      0.08      0.53      0.09     -0.85      0.90     69.43      0.90
# theta_decentered[24104,0,0]      0.11      1.75     -0.02     -2.85      2.90    118.53      0.91
# theta_decentered[24105,0,0]     -0.03      0.28      0.00     -0.48      0.34     39.22      1.02
# theta_decentered[24106,0,0]     -0.08      0.69     -0.16     -1.21      1.12    -38.21      0.90
# theta_decentered[24107,0,0]      0.05      0.42      0.04     -0.91      0.83     31.50      0.91
# theta_decentered[24108,0,0]      0.11      1.14      0.05     -1.86      1.76     14.65      0.95
# theta_decentered[24109,0,0]     -0.21      0.81     -0.49     -1.35      1.09     21.13      0.90
# theta_decentered[24110,0,0]      0.23      0.90      0.25     -1.24      1.30    -63.38      0.90
# theta_decentered[24111,0,0]      0.11      1.89      0.12     -2.66      2.91     47.03      0.92
# theta_decentered[24112,0,0]      0.06      1.55      0.05     -2.15      2.24     61.22      0.93
# theta_decentered[24113,0,0]     -0.02      1.02      0.12     -1.51      1.55     50.40      0.96
# theta_decentered[24114,0,0]      0.07      0.53      0.00     -0.64      0.85   -115.46      0.92
# theta_decentered[24115,0,0]     -0.04      1.28     -0.01     -1.83      1.68     37.75      0.94
# theta_decentered[24116,0,0]      0.16      1.05      0.44     -1.38      1.41    -48.59      0.90
# theta_decentered[24117,0,0]      0.01      0.91      0.02     -1.19      1.18   -206.50      0.95
# theta_decentered[24118,0,0]      0.05      1.37     -0.04     -2.24      2.29     33.80      0.91
#
# Number of divergences: 0
# Average Jensen-Shannon divergence across items= 0.16509295863653048
# Average KL divergence across items= 0.5397792015354385
# Binary F1 score with majority vote = 0.12284482758620689

# %%
posterior_samples = mcmc.get_samples()
predictive = Predictive(model, posterior_samples, infer_discrete=True)
# discrete_samples = predictive(random.PRNGKey(1), *train_data)
discrete_samples = predictive(random.PRNGKey(1), *(2,logits[:].shape[0],3, annotations,logits[:],mask))

# %%
annotator_probs = vmap(lambda x: x.mean(0), in_axes=1)(
    discrete_samples["y_unobserved"][:,train_size:],
)

pred_probs = np.vstack((annotator_probs.mean(1),1-annotator_probs.mean(1)))
emp_probs = np.vstack((annotations[train_size:].mean(1),1-annotations[train_size:].mean(1)))

print(f'Average Jensen-Shannon divergence across items= {np.power(jensenshannon(emp_probs,pred_probs),2).mean()}')
print(f'Average KL divergence across items= {entropy(emp_probs,pred_probs).mean()}')
print(f'Binary F1 score with majority vote = {f1_score(np.rint(annotations[train_size:].mean(1)),np.rint(np.rint(annotator_probs).mean(1)),pos_label=1)}')
# Out:
# Average Jensen-Shannon divergence across items= 0.16220774515307626
# Average KL divergence across items= 0.5238433605106096
# Binary F1 score with majority vote = 0.14330708661417324

# %%
discrete_samples["y_unobserved"][train_size:].shape
# Out:
# (0, 24119, 3)

# %%
posterior_samples['y'].shape
# Out:
# (500, 2, 1, 24119, 3)

# %%
discrete_samples.keys()
# Out:
# dict_keys(['c', 'y_observed', 'y_unobserved'])

# %%
yt = posterior_samples['y'][:,:,0,train_size:,:].transpose((0,2,1,3))

# %%
yt.shape
# Out:
# (500, 2412, 2, 3)

# %%
discrete_samples['c'].shape
# Out:
# (500, 2412, 1)

# %%
yt[0,0,discrete_samples['c'][0,0]]
# Out:
# Array([[0, 0, 0]], dtype=int32)

# %%
c=discrete_samples['c']

# %%
# First, remove the singleton dimension from c if needed
c_idx = jnp.squeeze(c, axis=-1)  # shape: (500, 2412)

# Use jnp.take_along_axis to index the 3rd dimension (axis=2)
# yt shape: (500, 2412, 2, 3) --> we want to select 1 from axis=2

# Expand c_idx to match yt's shape along axis=2
c_idx_exp = c_idx[..., None, None]  # shape: (500, 2412, 1, 1)

# Tile to shape: (500, 2412, 1, 3) to match yt
c_idx_exp = jnp.tile(c_idx_exp, (1, 1, 1, 3))

# Now gather along axis=2
a = jnp.take_along_axis(yt, c_idx_exp, axis=2)  # shape: (500, 2412, 1, 3)

# Squeeze out the axis=2
a = jnp.squeeze(a, axis=2)  # shape: (500, 2412, 3)

# %%
a.shape
# Out:
# (500, 2412, 3)

# %%
ys=jnp.take(yt,discrete_samples["c"],axis=2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 ys=jnp.take(yt,discrete_samples["c"],axis=2)
#
# NameError: name 'jnp' is not defined

# %%
discrete_samples['c'].shape
# Out:
# (500, 2412, 1)

# %%
annotator_probs = vmap(lambda x: x.mean(0), in_axes=1)(
    posterior_samples["y"][:,train_size:]
)

pred_probs = np.vstack((annotator_probs.mean(1),1-annotator_probs.mean(1)))
emp_probs = np.vstack((annotations[train_size:].mean(1),1-annotations[train_size:].mean(1)))

print(f'Average Jensen-Shannon divergence across items= {np.power(jensenshannon(emp_probs,pred_probs),2).mean()}')
print(f'Average KL divergence across items= {entropy(emp_probs,pred_probs).mean()}')
print(f'Binary F1 score with majority vote = {f1_score(np.rint(annotations[train_size:].mean(1)),np.rint(np.rint(annotator_probs).mean(1)),pos_label=1)}')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[38], line 8
#       5 pred_probs = np.vstack((annotator_probs.mean(1),1-annotator_probs.mean(1)))
#       6 emp_probs = np.vstack((annotations[train_size:].mean(1),1-annotations[train_size:].mean(1)))
# ----> 8 print(f'Average Jensen-Shannon divergence across items= {np.power(jensenshannon(emp_probs,pred_probs),2).mean()}')
#       9 print(f'Average KL divergence across items= {entropy(emp_probs,pred_probs).mean()}')
#      10 print(f'Binary F1 score with majority vote = {f1_score(np.rint(annotations[train_size:].mean(1)),np.rint(np.rint(annotator_probs).mean(1)),pos_label=1)}')
#
# File ~\miniconda3\envs\pyro\lib\site-packages\scipy\spatial\distance.py:1383, in jensenshannon(p, q, base, axis, keepdims)
#    1381 p = p / np.sum(p, axis=axis, keepdims=True)
#    1382 q = q / np.sum(q, axis=axis, keepdims=True)
# -> 1383 m = (p + q) / 2.0
#    1384 left = rel_entr(p, m)
#    1385 right = rel_entr(q, m)
#
# ValueError: operands could not be broadcast together with shapes (2,2412) (0,24119,3)

# %%
annotator_probs.shape
# Out:
# (24119, 3)

# %%
discrete_samples["y_unobserved"][train_size:].shape
# Out:
# (0, 24119, 3)

# %%
posterior_samples.keys()
# Out:
# dict_keys(['y', 'zeta'])

# %%
posterior_samples['y'].shape
# Out:
# (500, 2, 1, 24119, 3)

# %%
discrete_samples['c'].shape
# Out:
# (500, 2412, 1)

# %%
posterior_samples['y'][:,:,:,train_size:,:].shape
# Out:
# (500, 2, 1, 2412, 3)

# %%
y = posterior_samples['y'][:,:,:,train_size:,:]

# %%
a = np.empty(discrete_samples['c'].shape)

# %%
a=np.tile(a,(1,1,3))

# %%
yt=y.transpose((0,3,1,4,2))

# %%
for i in range(500):
    for j in range(2412):
        a[i,j] = y[i,discrete_samples['c'][i,j],0,j,:]

# %%
a.shape
# Out:
# (500, 2412, 3)

# %%
discrete_samples['c'].shape
# Out:
# (500, 2412, 1)

# %%
yt[discrete_samples['c']]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 yt[discrete_samples['c']]
#
# NameError: name 'yt' is not defined

# %%
annotator_probs = vmap(lambda x: x.mean(0), in_axes=1)(
    a
)

pred_probs = np.vstack((annotator_probs.mean(1),1-annotator_probs.mean(1)))
emp_probs = np.vstack((annotations[train_size:].mean(1),1-annotations[train_size:].mean(1)))

print(f'Average Jensen-Shannon divergence across items= {np.power(jensenshannon(emp_probs,pred_probs),2).mean()}')
print(f'Average KL divergence across items= {entropy(emp_probs,pred_probs).mean()}')
print(f'Binary F1 score with majority vote = {f1_score(np.rint(annotations[train_size:].mean(1)),np.rint(np.rint(annotator_probs).mean(1)),pos_label=1)}')
# Out:
# Average Jensen-Shannon divergence across items= 0.06398697845361095
# Average KL divergence across items= inf
# Binary F1 score with majority vote = 0.45874587458745875

# %%
discrete_samples["y_unobserved"][train_size:]
# Out:
# Array([], shape=(0, 24119, 3), dtype=int32)

# %%
predictive = Predictive(model, posterior_samples, infer_discrete=True)
discrete_samples = predictive(random.PRNGKey(1), *test_data)

# %%
for i in range(0,500):
    with numpyro.plate("item", discrete_samples["c"].shape[1], dim=-2):
        c = discrete_samples["c"][i]
        with numpyro.plate("position", 3):
            y = numpyro.sample("y", dist.Categorical(posterior_samples['zeta'][i][c]),rng_key=random.PRNGKey(1))
    if i == 0:
        ys=y
    elif i == 1:
        ys = np.vstack((ys[np.newaxis,...],y[np.newaxis,...]))
    else:
        ys = np.vstack((ys,y[np.newaxis,...]))

# %%
with numpyro.plate("my_plate1", 3):
    a =  numpyro.sample('a', dist.Bernoulli(0.5),rng_key=random.PRNGKey(1))
    b = numpyro.sample('b',  dist.Bernoulli(0.5),rng_key=random.PRNGKey(1))
    with numpyro.plate("my_plate2", 2):
        c = numpyro.sample('c', dist.Bernoulli(0.5),rng_key=random.PRNGKey(1))

# %%
print(a.shape)
print(b.shape)
print(c.shape)
# Out:
# (3,)
# (3,)
# (2, 3)
